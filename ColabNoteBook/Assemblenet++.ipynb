# %% [markdown]
# <a href="https://colab.research.google.com/github/shahidakhtarkhan/CV_ML_Projects/blob/main/ColabNoteBook/Assemblenet%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone \
  --depth 1  \
  --filter=blob:none  \
  --no-checkout \
  https://github.com/google-research/google-research.git

# %%
! git clone --depth 1 --filter=blob:none --no-checkout https://github.com/google-research/google-research.git
# Out:
# Cloning into 'google-research'...
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (1342/1342), done.
# remote: Compressing objects: 100% (1005/1005), done.
# remote: Total 1342 (delta 17), reused 1159 (delta 17), pack-reused 0
# Receiving objects: 100% (1342/1342), 358.20 KiB | 11.19 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# %cd google-research
# Out:
# /content/google-research

# %%
! git checkout master -- assemblenet
# Out:
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (1/1), 2.86 KiB | 2.86 MiB/s, done.
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (1/1), 428 bytes | 428.00 KiB/s, done.
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 1 (delta 0), pack-reused 0
# Receiving objects: 100% (1/1), 7.32 KiB | 7.32 MiB/s, done.
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (1/1), 5.25 KiB | 5.25 MiB/s, done.
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1 (delta 0), reused 1 (delta 0), pack-reused 0
# ...

# %%
! pwd
# Out:
# /content/google-research

# %%
# %cd assemblenet/
# Out:
# /content/google-research/assemblenet

# %%
cd ..
# Out:
# /content/google-research

# %%
# !pip install -r assemblenet/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 412.3MB 37kB/s
# ...
#      |████████████████████████████████| 3.8MB 45.2MB/s
# ...
#      |████████████████████████████████| 51kB 7.9MB/s
# ...
#      |████████████████████████████████| 512kB 51.9MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=79dc40af289e2583b3262442921d53b96d8d80ce95f23aaba4d6bffdbf243a3f
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
# ...

# %%
# !python -m assemblenet.run_asn --assemblenet_mode=assemblenet
# Out:
# WARNING:tensorflow:From /content/google-research/assemblenet/run_asn.py:72: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0331 05:41:25.743598 139689162672000 module_wrapper.py:139] From /content/google-research/assemblenet/run_asn.py:72: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:[[-1, 4], [-1, 4], [-2, 1], [-2, 1], [0, [1], 32, 1, 1, 0], [0, [0], 32, 4, 1, 0], [0, [0, 1, 2, 3], 32, 1, 1, 0], [0, [2, 3], 32, 2, 1, 0], [1, [0, 4, 5, 6, 7], 64, 2, 2, 0], [1, [0, 2, 4, 7], 64, 1, 2, 0], [1, [0, 5, 7], 64, 4, 2, 0], [1, [0, 5], 64, 1, 2, 0], [2, [4, 8, 10, 11], 256, 1, 2, 0], [2, [8, 9], 256, 4, 2, 0], [3, [12, 13], 512, 2, 2, 0]]
# ...

# %%
# !python -m assemblenet.run_asn --assemblenet_mode=assemblenet_plus_lite
# Out:
# WARNING:tensorflow:From /content/google-research/assemblenet/run_asn.py:72: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0331 05:44:15.867692 139727962351488 module_wrapper.py:139] From /content/google-research/assemblenet/run_asn.py:72: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:[[-1, 1], [-2, 1], [0, [0, 1], [27, 27, 12], 1, 2, 0], [0, [0, 1], [27, 27, 12], 4, 2, 0], [1, [0, 1, 2, 3], [54, 54, 24], 2, 2, 0], [1, [0, 1, 2, 3], [54, 54, 24], 1, 2, 0], [1, [0, 1, 2, 3], [54, 54, 24], 4, 2, 0], [1, [0, 1, 2, 3], [54, 54, 24], 1, 2, 0], [2, [0, 1, 2, 3, 4, 5, 6, 7], [152, 152, 68], 1, 2, 0], [2, [0, 1, 2, 3, 4, 5, 6, 7], [152, 152, 68], 4, 2, 0], [3, [2, 3, 4, 5, 6, 7, 8, 9], [432, 432, 192], 2, 2, 0]]
# ...

# %%
# !python -m assemblenet.run_asn_with_object --assemblenet_mode=assemblenet_plus_lite
# Out:
# WARNING:tensorflow:From /content/google-research/assemblenet/run_asn_with_object.py:70: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0331 05:50:33.134635 140595302811520 module_wrapper.py:139] From /content/google-research/assemblenet/run_asn_with_object.py:70: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:[[-1, 2], [-1, 4], [-2, 2], [-2, 1], [-3, 4], [0, [0, 1, 2, 3, 4], 32, 1, 1, 0], [0, [0, 1, 4], 32, 4, 1, 0], [0, [2, 3, 4], 32, 8, 1, 0], [0, [2, 3, 4], 32, 1, 1, 0], [1, [0, 1, 2, 4, 5, 6, 7, 8], 64, 4, 2, 0], [1, [2, 3, 4, 7, 8], 64, 1, 2, 0], [1, [0, 4, 5, 6, 7], 128, 8, 2, 0], [2, [4, 11], 256, 8, 2, 0], [2, [2, 3, 4, 5, 6, 7, 8, 10, 11], 256, 4, 2, 0], [3, [12, 13], 512, 2, 2, 0]]
# ...
