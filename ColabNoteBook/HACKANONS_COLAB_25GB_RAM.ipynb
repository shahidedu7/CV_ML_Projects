# %% [markdown]
# <a href="https://colab.research.google.com/github/shahidakhtarkhan/CV_ML_Projects/blob/main/ColabNoteBook/HACKANONS_COLAB_25GB_RAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section
