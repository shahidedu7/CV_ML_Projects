# %% [markdown]
# <a href="https://colab.research.google.com/github/shahidakhtarkhan/CV_ML_Projects/blob/main/2s_AGCN_without_refined.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
! git clone https://github.com/YangDi666/2s-AGCN-For-Daily-Living.git
# Out:
# Cloning into '2s-AGCN-For-Daily-Living'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 87 (delta 29), reused 61 (delta 15), pack-reused 0
# Unpacking objects: 100% (87/87), done.

# %%
! pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 7.6MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.19.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (56.0.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.2

# %%
cd 2s-AGCN-For-Daily-Living/data_gen/
# Out:
# /content/gdrive/My Drive/2s-AGCN-For-Daily-Living/data_gen

# %%
! python smarthome_gendata.py
# Out:
# raw_path:  /content/gdrive/MyDrive/Toyota Skeleton dataset/toyota_smarthome_skeleton/json/
# xsub train
# tcmalloc: large alloc 7691042816 bytes == 0x564c03dd2000 @  0x7f352546e001 0x7f3522c1a54f 0x7f3522c6ab58 0x7f3522c6eb17 0x7f3522d0d203 0x564c01fd00e4 0x564c01fcfde0 0x564c020446f5 0x564c0203eb0e 0x564c01fd177a 0x564c0204086a 0x564c0203eb0e 0x564c0203e813 0x564c02108592 0x564c0210890d 0x564c021087b6 0x564c020e0103 0x564c020dfdac 0x7f3524256bf7 0x564c020dfc8a
# 100% 10682/10682 [1:46:03<00:00,  1.68it/s]
# xsub val
# tcmalloc: large alloc 3911761920 bytes == 0x564c03dd2000 @  0x7f352546e001 0x7f3522c1a54f 0x7f3522c6ab58 0x7f3522c6eb17 0x7f3522d0d203 0x564c01fd00e4 0x564c01fcfde0 0x564c020446f5 0x564c0203eb0e 0x564c01fd177a 0x564c0204086a 0x564c0203eb0e 0x564c0203e813 0x564c02108592 0x564c0210890d 0x564c021087b6 0x564c020e0103 0x564c020dfdac 0x7f3524256bf7 0x564c020dfc8a
# 100% 5433/5433 [54:10<00:00,  1.67it/s]
# 100% 5433/5433 [54:10<00:00,  1.67it/s]
# 100% 5433/5433 [54:10<00:00,  1.67it/s]

# %%
! python smarthome_gendata.py
# Out:
# raw_path:  /content/gdrive/MyDrive/Toyota Skeleton dataset/toyota_smarthome_skeleton/json/
# xsub val
# tcmalloc: large alloc 3911761920 bytes == 0x5619733c4000 @  0x7f0e19cf6001 0x7f0e174e254f 0x7f0e17532b58 0x7f0e17536b17 0x7f0e175d5203 0x5619715220e4 0x561971521de0 0x5619715966f5 0x561971590b0e 0x56197152377a 0x56197159286a 0x561971590b0e 0x561971590813 0x56197165a592 0x56197165a90d 0x56197165a7b6 0x561971632103 0x561971631dac 0x7f0e18adebf7 0x561971631c8a
# 100% 5433/5433 [28:33<00:00,  3.17it/s]
# xsub train
# tcmalloc: large alloc 7691042816 bytes == 0x561a5ce96000 @  0x7f0e19cf6001 0x7f0e174e254f 0x7f0e17532b58 0x7f0e17536b17 0x7f0e175d5203 0x5619715220e4 0x561971521de0 0x5619715966f5 0x561971590b0e 0x56197152377a 0x56197159286a 0x561971590b0e 0x561971590813 0x56197165a592 0x56197165a90d 0x56197165a7b6 0x561971632103 0x561971631dac 0x7f0e18adebf7 0x561971631c8a
#  51% 5430/10682 [29:52<25:12,  3.47it/s]Traceback (most recent call last):
#   File "smarthome_gendata.py", line 175, in <module>
#     part=p)
#   File "smarthome_gendata.py", line 146, in gendata
#     data = read_xyz(os.path.join(data_path, s), max_body=max_body, num_joint=num_joint)
#   File "smarthome_gendata.py", line 58, in read_xyz
#     seq_info = read_skeleton_filter(file)
#   File "smarthome_gendata.py", line 42, in read_skeleton_filter
#     skeleton_sequence = json.load(json_data)
#   File "/usr/lib/python3.7/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.7/codecs.py", line 319, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
#  51% 5430/10682 [29:53<28:54,  3.03it/s]

# %%
! pwd
# Out:
# /content/gdrive/MyDrive/2s-AGCN-For-Daily-Living

# %% [markdown]
# Test with weight 1 and batch = 16

# %%
cd ..
# Out:
# /content/gdrive/MyDrive/2s-AGCN-For-Daily-Living

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l2): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l3): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l4): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l5): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l6): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l7): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l8): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l9): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l10): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (fc): Linear(in_features=256, out_features=31, bias=True)
# )
# [ Thu May  6 08:54:05 2021 ] Load weights from ./runs/smarthome_cs_agcn_joint_skeleton1-35-24012.pt.
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [ Thu May  6 08:54:05 2021 ] using warm up, epoch: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [ Thu May  6 08:54:05 2021 ] Model:   model.agcn.Model.
# [ Thu May  6 08:54:05 2021 ] Weights: ./runs/smarthome_cs_agcn_joint_skeleton1-35-24012.pt.
# [ Thu May  6 08:54:05 2021 ] Eval epoch: 1
#   0% 0/340 [00:00<?, ?it/s]main.py:459: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# main.py:463: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# 100% 340/340 [06:54<00:00,  1.22s/it]
# Accuracy:  0.7032946806552549  model:  ./runs/smarthome_cs_agcn_test_joint
# [ Thu May  6 09:01:00 2021 ] 	Mean test loss of 340 batches: 1.18965470653356.
# [ Thu May  6 09:01:00 2021 ] 	Top1: 70.33%
# [ Thu May  6 09:01:00 2021 ] 	Top5: 92.34%
# [ Thu May  6 09:01:01 2021 ] Done.

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.5639097744360902
# accuracy_Cook.Cleanup :  0.4485981308411215
# accuracy_Cook.Cut :  0.5
# accuracy_Cook.Stir :  0.7236180904522613
# accuracy_Cook.Usestove :  0.2777777777777778
# accuracy_Cutbread :  0.2
# accuracy_Drink.Frombottle :  0.38636363636363635
# accuracy_Drink.Fromcan :  0.11764705882352941
# accuracy_Drink.Fromcup :  0.8139223560910308
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.7114624505928854
# accuracy_Eat.Snack :  0.25
# accuracy_Enter :  0.706766917293233
# accuracy_Getup :  0.8769716088328076
# accuracy_Laydown :  0.7846153846153846
# accuracy_Leave :  0.6728971962616822
# accuracy_Makecoffee.Pourgrains :  0.0
# accuracy_Makecoffee.Pourwater :  0.6296296296296297
# accuracy_Maketea.Boilwater :  0.5
# accuracy_Maketea.Insertteabag :  0.25
# accuracy_Pour.Frombottle :  0.6538461538461539
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.5
# accuracy_Readbook :  0.4880239520958084
# accuracy_Sitdown :  0.9225512528473804
# accuracy_Takepills :  0.42028985507246375
# accuracy_Uselaptop :  0.43258426966292135
# accuracy_Usetelephone :  0.6326530612244898
# accuracy_Usetablet :  0.0
# accuracy_Walk :  0.9159256265157639
# accuracy_WatchTV :  0.47391304347826085
#
# total accuracy:  0.7032946806552549
#
# average accuracy:  0.4791602331211068
# Figure saved as confusion_matrix.png

# %% [markdown]
# Test with weight1 and batch32

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l2): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l3): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l4): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l5): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l6): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l7): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l8): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l9): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l10): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (fc): Linear(in_features=256, out_features=31, bias=True)
# )
# [ Thu May  6 09:11:20 2021 ] Load weights from ./runs/smarthome_cs_agcn_joint_skeleton1-35-24012.pt.
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [ Thu May  6 09:11:20 2021 ] using warm up, epoch: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [ Thu May  6 09:11:20 2021 ] Model:   model.agcn.Model.
# [ Thu May  6 09:11:20 2021 ] Weights: ./runs/smarthome_cs_agcn_joint_skeleton1-35-24012.pt.
# [ Thu May  6 09:11:20 2021 ] Eval epoch: 1
#   0% 0/170 [00:00<?, ?it/s]main.py:459: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# main.py:463: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# 100% 170/170 [07:11<00:00,  2.54s/it]
# Accuracy:  0.7032946806552549  model:  ./runs/smarthome_cs_agcn_test_joint
# [ Thu May  6 09:18:32 2021 ] 	Mean test loss of 170 batches: 1.190239370762206.
# [ Thu May  6 09:18:32 2021 ] 	Top1: 70.33%
# [ Thu May  6 09:18:32 2021 ] 	Top5: 92.34%
# [ Thu May  6 09:18:32 2021 ] Done.

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.5639097744360902
# accuracy_Cook.Cleanup :  0.4485981308411215
# accuracy_Cook.Cut :  0.5
# accuracy_Cook.Stir :  0.7236180904522613
# accuracy_Cook.Usestove :  0.2777777777777778
# accuracy_Cutbread :  0.2
# accuracy_Drink.Frombottle :  0.38636363636363635
# accuracy_Drink.Fromcan :  0.11764705882352941
# accuracy_Drink.Fromcup :  0.8139223560910308
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.7114624505928854
# accuracy_Eat.Snack :  0.25
# accuracy_Enter :  0.706766917293233
# accuracy_Getup :  0.8769716088328076
# accuracy_Laydown :  0.7846153846153846
# accuracy_Leave :  0.6728971962616822
# accuracy_Makecoffee.Pourgrains :  0.0
# accuracy_Makecoffee.Pourwater :  0.6296296296296297
# accuracy_Maketea.Boilwater :  0.5
# accuracy_Maketea.Insertteabag :  0.25
# accuracy_Pour.Frombottle :  0.6538461538461539
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.5
# accuracy_Readbook :  0.4880239520958084
# accuracy_Sitdown :  0.9225512528473804
# accuracy_Takepills :  0.42028985507246375
# accuracy_Uselaptop :  0.43258426966292135
# accuracy_Usetelephone :  0.6326530612244898
# accuracy_Usetablet :  0.0
# accuracy_Walk :  0.9159256265157639
# accuracy_WatchTV :  0.47391304347826085
#
# total accuracy:  0.7032946806552549
#
# average accuracy:  0.4791602331211068
# Figure saved as confusion_matrix.png

# %% [markdown]
# ## **Test with weight2**
# batch = 32

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l2): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l3): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l4): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l5): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l6): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l7): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l8): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l9): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l10): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (fc): Linear(in_features=256, out_features=31, bias=True)
# )
# [ Thu May  6 09:26:23 2021 ] Load weights from ./runs/smarthome_cs_agcn_joint_skeleton2-33-22678.pt.
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [ Thu May  6 09:26:23 2021 ] using warm up, epoch: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [ Thu May  6 09:26:24 2021 ] Model:   model.agcn.Model.
# [ Thu May  6 09:26:24 2021 ] Weights: ./runs/smarthome_cs_agcn_joint_skeleton2-33-22678.pt.
# [ Thu May  6 09:26:24 2021 ] Eval epoch: 1
#   0% 0/170 [00:00<?, ?it/s]main.py:459: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# main.py:463: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# 100% 170/170 [07:14<00:00,  2.56s/it]
# Accuracy:  0.5083747469169888  model:  ./runs/smarthome_cs_agcn_test_joint
# [ Thu May  6 09:33:38 2021 ] 	Mean test loss of 170 batches: 2.312076784451218.
# [ Thu May  6 09:33:38 2021 ] 	Top1: 50.84%
# [ Thu May  6 09:33:38 2021 ] 	Top5: 79.64%
# [ Thu May  6 09:33:38 2021 ] Done.

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.2556390977443609
# accuracy_Cook.Cleanup :  0.45794392523364486
# accuracy_Cook.Cut :  0.17647058823529413
# accuracy_Cook.Stir :  0.25125628140703515
# accuracy_Cook.Usestove :  0.16666666666666666
# accuracy_Cutbread :  0.0
# accuracy_Drink.Frombottle :  0.36363636363636365
# accuracy_Drink.Fromcan :  0.37815126050420167
# accuracy_Drink.Fromcup :  0.4390896921017403
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.37549407114624506
# accuracy_Eat.Snack :  0.09615384615384616
# accuracy_Enter :  0.5263157894736842
# accuracy_Getup :  0.8422712933753943
# accuracy_Laydown :  0.8461538461538461
# accuracy_Leave :  0.037383177570093455
# accuracy_Makecoffee.Pourgrains :  0.09523809523809523
# accuracy_Makecoffee.Pourwater :  0.5925925925925926
# accuracy_Maketea.Boilwater :  0.0
# accuracy_Maketea.Insertteabag :  0.0
# accuracy_Pour.Frombottle :  0.20192307692307693
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.2857142857142857
# accuracy_Readbook :  0.08083832335329341
# accuracy_Sitdown :  0.876993166287016
# accuracy_Takepills :  0.42028985507246375
# accuracy_Uselaptop :  0.24157303370786518
# accuracy_Usetelephone :  0.564625850340136
# accuracy_Usetablet :  0.0
# accuracy_Walk :  0.8084074373484236
# accuracy_WatchTV :  0.23478260869565218
#
# total accuracy:  0.5083747469169888
#
# average accuracy:  0.3101807814411392
# Figure saved as confusion_matrix.png

# %% [markdown]
# # Test with weight 3

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l2): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l3): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l4): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(64, 64, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l5): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l6): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l7): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l8): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(2, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#     (residual): unit_tcn(
#       (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 1))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#   )
#   (l9): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (l10): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (soft): Softmax(dim=-2)
#       (relu): ReLU()
#     )
#     (tcn1): unit_tcn(
#       (conv): Conv2d(256, 256, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#       (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (relu): ReLU()
#   )
#   (fc): Linear(in_features=256, out_features=31, bias=True)
# )
# [ Thu May  6 09:45:11 2021 ] Load weights from ./runs/smarthome_cs_agcn_joint_skeleton3-53-36018.pt.
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# [ Thu May  6 09:45:11 2021 ] using warm up, epoch: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [ Thu May  6 09:45:11 2021 ] Model:   model.agcn.Model.
# [ Thu May  6 09:45:11 2021 ] Weights: ./runs/smarthome_cs_agcn_joint_skeleton3-53-36018.pt.
# [ Thu May  6 09:45:11 2021 ] Eval epoch: 1
#   0% 0/170 [00:00<?, ?it/s]main.py:459: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# main.py:463: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   volatile=True)
# 100% 170/170 [07:11<00:00,  2.54s/it]
# Accuracy:  0.5654334621755936  model:  ./runs/smarthome_cs_agcn_test_joint
# [ Thu May  6 09:52:23 2021 ] 	Mean test loss of 170 batches: 2.396979862013284.
# [ Thu May  6 09:52:23 2021 ] 	Top1: 56.54%
# [ Thu May  6 09:52:23 2021 ] 	Top5: 81.70%
# [ Thu May  6 09:52:23 2021 ] Done.

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.21804511278195488
# accuracy_Cook.Cleanup :  0.6074766355140186
# accuracy_Cook.Cut :  0.36764705882352944
# accuracy_Cook.Stir :  0.6532663316582915
# accuracy_Cook.Usestove :  0.2777777777777778
# accuracy_Cutbread :  0.05
# accuracy_Drink.Frombottle :  0.22727272727272727
# accuracy_Drink.Fromcan :  0.2184873949579832
# accuracy_Drink.Fromcup :  0.642570281124498
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.525691699604743
# accuracy_Eat.Snack :  0.09615384615384616
# accuracy_Enter :  0.6616541353383458
# accuracy_Getup :  0.7570977917981072
# accuracy_Laydown :  0.7230769230769231
# accuracy_Leave :  0.12149532710280374
# accuracy_Makecoffee.Pourgrains :  0.0
# accuracy_Makecoffee.Pourwater :  0.6296296296296297
# accuracy_Maketea.Boilwater :  0.0625
# accuracy_Maketea.Insertteabag :  0.1
# accuracy_Pour.Frombottle :  0.33653846153846156
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.21428571428571427
# accuracy_Readbook :  0.1377245508982036
# accuracy_Sitdown :  0.8223234624145785
# accuracy_Takepills :  0.3695652173913043
# accuracy_Uselaptop :  0.34831460674157305
# accuracy_Usetelephone :  0.4489795918367347
# accuracy_Usetablet :  0.06666666666666667
# accuracy_Walk :  0.8334680679062247
# accuracy_WatchTV :  0.33043478260869563
#
# total accuracy:  0.5654334621755936
#
# average accuracy:  0.3499401224162367
# Figure saved as confusion_matrix.png
